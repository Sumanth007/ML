# %%
import pandas as p

# %%
data = p.read_csv(r"C:\Users\suman\Downloads\ML_Datasets-20230613T052137Z-001\ML_Datasets\Salaries.csv")

# %%
k = data.groupby('discipline')

# %%
print(k)

# %%
print(k)

# %%
for i in k:
    print(i)
# Out:
# ('A',      Unnamed: 0      rank discipline  yrs.since.phd  yrs.service     sex  \
# 17           18      Prof          A             38           34    Male
# 18           19      Prof          A             37           23    Male
# 19           20      Prof          A             39           36  Female
# 20           21      Prof          A             31           26    Male
# 21           22      Prof          A             36           31    Male
# ..          ...       ...        ...            ...          ...     ...
# 392         393      Prof          A             33           30    Male
# 393         394      Prof          A             31           19    Male
# 394         395      Prof          A             42           25    Male
# 395         396      Prof          A             25           15    Male
# 396         397  AsstProf          A              8            4    Male
#
#      salary
# 17   103450
# 18   124750
# 19   137000
# 20    89565
# 21   102580
# ...

# %%
k.groups.keys()
# Out:
# dict_keys(['A', 'B'])

# %%
d2 = k.get_group('A')
d2
# Out:
#      Unnamed: 0      rank discipline  yrs.since.phd  yrs.service     sex  \
# 17           18      Prof          A             38           34    Male
# 18           19      Prof          A             37           23    Male
# 19           20      Prof          A             39           36  Female
# 20           21      Prof          A             31           26    Male
# 21           22      Prof          A             36           31    Male
# ..          ...       ...        ...            ...          ...     ...
# 392         393      Prof          A             33           30    Male
# 393         394      Prof          A             31           19    Male
# 394         395      Prof          A             42           25    Male
# 395         396      Prof          A             25           15    Male
# 396         397  AsstProf          A              8            4    Male
#
#      salary
# 17   103450
# 18   124750
# 19   137000
# 20    89565
# 21   102580
# ...

# %%
d2.head(10)
# Out:
#     Unnamed: 0       rank discipline  yrs.since.phd  yrs.service     sex  \
# 17          18       Prof          A             38           34    Male
# 18          19       Prof          A             37           23    Male
# 19          20       Prof          A             39           36  Female
# 20          21       Prof          A             31           26    Male
# 21          22       Prof          A             36           31    Male
# 22          23       Prof          A             34           30    Male
# 23          24       Prof          A             24           19    Male
# 24          25  AssocProf          A             13            8  Female
# 25          26       Prof          A             21            8    Male
# 26          27       Prof          A             35           23    Male
#
#     salary
# 17  103450
# 18  124750
# 19  137000
# 20   89565
# 21  102580
# 22   93904
# 23  113068
# 24   74830
# 25  106294
# 26  134885

# %%
data.tail(5)
# Out:
#      Unnamed: 0      rank discipline  yrs.since.phd  yrs.service   sex  salary
# 392         393      Prof          A             33           30  Male  103106
# 393         394      Prof          A             31           19  Male  150564
# 394         395      Prof          A             42           25  Male  101738
# 395         396      Prof          A             25           15  Male   95329
# 396         397  AsstProf          A              8            4  Male   81035

# %%
data.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0      rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0             1      Prof          B             19           18  Male  139750
# 1             2      Prof          B             20           16  Male  173200
# 2             3  AsstProf          B              4            3  Male   79750
# 3             4      Prof          B             45           39  Male  115000
# 4             5      Prof          B             40           41  Male  141500
# ..          ...       ...        ...            ...          ...   ...     ...
# 392         393      Prof          A             33           30  Male  103106
# 393         394      Prof          A             31           19  Male  150564
# 394         395      Prof          A             42           25  Male  101738
# 395         396      Prof          A             25           15  Male   95329
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     397 non-null    int64
#  1   rank           397 non-null    object
#  2   discipline     397 non-null    object
#  3   yrs.since.phd  397 non-null    int64
#  4   yrs.service    397 non-null    int64
#  5   sex            397 non-null    object
#  6   salary         397 non-null    int64
# dtypes: int64(4), object(3)
# memory usage: 21.8+ KB

# %%
data[['salary']]
# Out:
#      salary
# 0    139750
# 1    173200
# 2     79750
# 3    115000
# 4    141500
# ..      ...
# 392  103106
# 393  150564
# 394  101738
# 395   95329
# 396   81035
#
# [397 rows x 1 columns]

# %%
data.iloc[:,6]
# Out:
# 0      139750
# 1      173200
# 2       79750
# 3      115000
# 4      141500
#         ...
# 392    103106
# 393    150564
# 394    101738
# 395     95329
# 396     81035
# Name: salary, Length: 397, dtype: int64

# %%
data.iloc[1,6]
# Out:
# 173200

# %%
data.iloc[1:6,6]
# Out:
# 1    173200
# 2     79750
# 3    115000
# 4    141500
# 5     97000
# Name: salary, dtype: int64

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
data.count
# Out:
# <bound method DataFrame.count of      Unnamed: 0      rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0             1      Prof          B             19           18  Male  139750
# 1             2      Prof          B             20           16  Male  173200
# 2             3  AsstProf          B              4            3  Male   79750
# 3             4      Prof          B             45           39  Male  115000
# 4             5      Prof          B             40           41  Male  141500
# ..          ...       ...        ...            ...          ...   ...     ...
# 392         393      Prof          A             33           30  Male  103106
# 393         394      Prof          A             31           19  Male  150564
# 394         395      Prof          A             42           25  Male  101738
# 395         396      Prof          A             25           15  Male   95329
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of      Unnamed: 0      rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0             1      Prof          B             19           18  Male  139750
# 1             2      Prof          B             20           16  Male  173200
# 2             3  AsstProf          B              4            3  Male   79750
# 3             4      Prof          B             45           39  Male  115000
# 4             5      Prof          B             40           41  Male  141500
# ..          ...       ...        ...            ...          ...   ...     ...
# 392         393      Prof          A             33           30  Male  103106
# 393         394      Prof          A             31           19  Male  150564
# 394         395      Prof          A             42           25  Male  101738
# 395         396      Prof          A             25           15  Male   95329
# ...

# %%
data.shape
# Out:
# (397, 7)

# %%
data.ndim
# Out:
# 2

# %%
data.describe()
# Out:
#        Unnamed: 0  yrs.since.phd  yrs.service         salary
# count  397.000000     397.000000   397.000000     397.000000
# mean   199.000000      22.314861    17.614610  113706.458438
# std    114.748275      12.887003    13.006024   30289.038695
# min      1.000000       1.000000     0.000000   57800.000000
# 25%    100.000000      12.000000     7.000000   91000.000000
# 50%    199.000000      21.000000    16.000000  107300.000000
# 75%    298.000000      32.000000    27.000000  134185.000000
# max    397.000000      56.000000    60.000000  231545.000000

# %%
k = data.groupby('sex')

# %%
k

# %%
for i in k:
    print(i)
# Out:
# ('Female',      Unnamed: 0       rank discipline  yrs.since.phd  yrs.service     sex  \
# 9            10       Prof          B             18           18  Female
# 19           20       Prof          A             39           36  Female
# 24           25  AssocProf          A             13            8  Female
# 34           35   AsstProf          B              4            2  Female
# 35           36   AsstProf          B              5            0  Female
# 47           48       Prof          B             23           19  Female
# 48           49       Prof          B             25           25  Female
# 52           53   AsstProf          B             11            3  Female
# 63           64  AssocProf          B             11           11  Female
# 68           69       Prof          B             17           17  Female
# 84           85       Prof          B             17           18  Female
# ...

# %%
k.groups.keys()
# Out:
# dict_keys(['Female', 'Male'])

# %%
d3 = data[data['sex'] == 'Male']

# %%
len(d3)
# Out:
# 358

# %%
d3
# Out:
#      Unnamed: 0      rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0             1      Prof          B             19           18  Male  139750
# 1             2      Prof          B             20           16  Male  173200
# 2             3  AsstProf          B              4            3  Male   79750
# 3             4      Prof          B             45           39  Male  115000
# 4             5      Prof          B             40           41  Male  141500
# ..          ...       ...        ...            ...          ...   ...     ...
# 392         393      Prof          A             33           30  Male  103106
# 393         394      Prof          A             31           19  Male  150564
# 394         395      Prof          A             42           25  Male  101738
# 395         396      Prof          A             25           15  Male   95329
# 396         397  AsstProf          A              8            4  Male   81035
#
# [358 rows x 7 columns]

# %%
data[data['yrs.since.phd']>20]
# Out:
#      Unnamed: 0  rank discipline  yrs.since.phd  yrs.service   sex  salary
# 3             4  Prof          B             45           39  Male  115000
# 4             5  Prof          B             40           41  Male  141500
# 6             7  Prof          B             30           23  Male  175000
# 7             8  Prof          B             45           45  Male  147765
# 8             9  Prof          B             21           20  Male  119250
# ..          ...   ...        ...            ...          ...   ...     ...
# 391         392  Prof          A             30           19  Male  151292
# 392         393  Prof          A             33           30  Male  103106
# 393         394  Prof          A             31           19  Male  150564
# 394         395  Prof          A             42           25  Male  101738
# 395         396  Prof          A             25           15  Male   95329
#
# [204 rows x 7 columns]

# %%
data['yrs.since.phd']>20
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 392     True
# 393     True
# 394     True
# 395     True
# 396    False
# Name: yrs.since.phd, Length: 397, dtype: bool

# %%
data[(data['yrs.since.phd']>20) & (data['yrs.since.phd']<40)]
# Out:
#      Unnamed: 0  rank discipline  yrs.since.phd  yrs.service     sex  salary
# 6             7  Prof          B             30           23    Male  175000
# 8             9  Prof          B             21           20    Male  119250
# 17           18  Prof          A             38           34    Male  103450
# 18           19  Prof          A             37           23    Male  124750
# 19           20  Prof          A             39           36  Female  137000
# ..          ...   ...        ...            ...          ...     ...     ...
# 389         390  Prof          A             33           18    Male  186023
# 391         392  Prof          A             30           19    Male  151292
# 392         393  Prof          A             33           30    Male  103106
# 393         394  Prof          A             31           19    Male  150564
# 395         396  Prof          A             25           15    Male   95329
#
# [162 rows x 7 columns]

# %%
d4 = data[['yrs.service','rank']]

# %%
d4
# Out:
#      yrs.service      rank
# 0             18      Prof
# 1             16      Prof
# 2              3  AsstProf
# 3             39      Prof
# 4             41      Prof
# ..           ...       ...
# 392           30      Prof
# 393           19      Prof
# 394           25      Prof
# 395           15      Prof
# 396            4  AsstProf
#
# [397 rows x 2 columns]

# %%
d4n = d4[d4['rank']=='Prof']

# %%
d4n
# Out:
#      yrs.service  rank
# 0             18  Prof
# 1             16  Prof
# 3             39  Prof
# 4             41  Prof
# 6             23  Prof
# ..           ...   ...
# 391           19  Prof
# 392           30  Prof
# 393           19  Prof
# 394           25  Prof
# 395           15  Prof
#
# [266 rows x 2 columns]

# %%
d4n['yrs.service'].mean()
# Out:
# 22.81578947368421

# %%
d4n
# Out:
#      yrs.service  rank
# 0             18  Prof
# 1             16  Prof
# 3             39  Prof
# 4             41  Prof
# 6             23  Prof
# ..           ...   ...
# 391           19  Prof
# 392           30  Prof
# 393           19  Prof
# 394           25  Prof
# 395           15  Prof
#
# [266 rows x 2 columns]

# %%
d4n['yrs.service'].max()
# Out:
# 60

# %%
d4n['yrs.service'].min()
# Out:
# 0

# %%
d4n.index
# Out:
# Int64Index([  0,   1,   3,   4,   6,   7,   8,   9,  14,  15,
#             ...
#             386, 387, 388, 389, 390, 391, 392, 393, 394, 395],
#            dtype='int64', length=266)

# %%
d4n.set_index('rank')
# Out:
#       yrs.service
# rank
# Prof           18
# Prof           16
# Prof           39
# Prof           41
# Prof           23
# ...           ...
# Prof           19
# Prof           30
# Prof           19
# Prof           25
# Prof           15
#
# [266 rows x 1 columns]

# %%
d4n.index
# Out:
# Int64Index([  0,   1,   3,   4,   6,   7,   8,   9,  14,  15,
#             ...
#             386, 387, 388, 389, 390, 391, 392, 393, 394, 395],
#            dtype='int64', length=266)

# %%
data.set_index('salary')
# Out:
#         Unnamed: 0      rank discipline  yrs.since.phd  yrs.service   sex
# salary
# 139750           1      Prof          B             19           18  Male
# 173200           2      Prof          B             20           16  Male
# 79750            3  AsstProf          B              4            3  Male
# 115000           4      Prof          B             45           39  Male
# 141500           5      Prof          B             40           41  Male
# ...            ...       ...        ...            ...          ...   ...
# 103106         393      Prof          A             33           30  Male
# 150564         394      Prof          A             31           19  Male
# 101738         395      Prof          A             42           25  Male
# 95329          396      Prof          A             25           15  Male
# 81035          397  AsstProf          A              8            4  Male
#
# [397 rows x 6 columns]

# %%
data.index
# Out:
# RangeIndex(start=0, stop=397, step=1)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=397, step=1)

# %%
d5 = data.set_index('salary')

# %%
d5
# Out:
#         Unnamed: 0      rank discipline  yrs.since.phd  yrs.service   sex
# salary
# 139750           1      Prof          B             19           18  Male
# 173200           2      Prof          B             20           16  Male
# 79750            3  AsstProf          B              4            3  Male
# 115000           4      Prof          B             45           39  Male
# 141500           5      Prof          B             40           41  Male
# ...            ...       ...        ...            ...          ...   ...
# 103106         393      Prof          A             33           30  Male
# 150564         394      Prof          A             31           19  Male
# 101738         395      Prof          A             42           25  Male
# 95329          396      Prof          A             25           15  Male
# 81035          397  AsstProf          A              8            4  Male
#
# [397 rows x 6 columns]

# %%
data[data['yrs.since.phd']>20]
# Out:
#      Unnamed: 0  rank discipline  yrs.since.phd  yrs.service   sex  salary
# 3             4  Prof          B             45           39  Male  115000
# 4             5  Prof          B             40           41  Male  141500
# 6             7  Prof          B             30           23  Male  175000
# 7             8  Prof          B             45           45  Male  147765
# 8             9  Prof          B             21           20  Male  119250
# ..          ...   ...        ...            ...          ...   ...     ...
# 391         392  Prof          A             30           19  Male  151292
# 392         393  Prof          A             33           30  Male  103106
# 393         394  Prof          A             31           19  Male  150564
# 394         395  Prof          A             42           25  Male  101738
# 395         396  Prof          A             25           15  Male   95329
#
# [204 rows x 7 columns]

# %%
data['New Rank']

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv(r"C:\Users\suman\Downloads\ML_Datasets-20230613T052137Z-001\ML_Datasets\Salaries.csv")

# %%
data.sex.value_counts().plot.bar()
plt.show()

# %%
data.salary.value_counts().plot.bar()
plt.show()

# %%
data.sex.value_counts().plot.bar()
# Out:
# <Axes: >

# %%
# data.rank.value_counts().plot.bar()

# %%
data.index.value_counts().plot.bar(color="red")
# Out:
# <Axes: >

# %%
data.sex.value_counts()
# Out:
# Male      358
# Female     39
# Name: sex, dtype: int64

# %%
data.rank
# Out:
# <bound method NDFrame.rank of      index      rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0        1      Prof          B             19           18  Male  139750
# 1        2      Prof          B             20           16  Male  173200
# 2        3  AsstProf          B              4            3  Male   79750
# 3        4      Prof          B             45           39  Male  115000
# 4        5      Prof          B             40           41  Male  141500
# ..     ...       ...        ...            ...          ...   ...     ...
# 392    393      Prof          A             33           30  Male  103106
# 393    394      Prof          A             31           19  Male  150564
# 394    395      Prof          A             42           25  Male  101738
# 395    396      Prof          A             25           15  Male   95329
# 396    397  AsstProf          A              8            4  Male   81035
#
# [397 rows x 7 columns]>

# %%
data['rank'].value_counts().plot.bar(color="yellow")
plt.show()

# %%
l = [10,20,30,40,50,60]
g = [1,2,3,4,5,6]
u = [50,100,150,200,250,300]
t = [4,8,12,16,20,24]
plt.plot(l,g,'b',u,'y',t,'r')
plt.show()

# %%
plt.plot(g,linestyle="dashed")
plt.title("Legacy",loc = 'left')
plt.xlabel("x")
plt.ylabel("y")
plt.grid(axis="x")
plt.grid(axis="y")
plt.show()

# %%
d1 = data[(data['rank']=='Prof') & (data['yrs.service']>15)]
d2 = (data['rank']=='Prof') & (data['yrs.service']>15)

# d1.head(10).plot()
d3 = data[d2]
t1 = d3['yrs.service'].head(10)
t2 = d3['salary'].head(10)
plt.plot(t1,t2)
plt.show()

# %%
plt.plot(d1['yrs.service'],d1['salary'])
plt.show()

# %%
plt.subplot(2,1,1)
plt.plot(d1['salary'])

plt.subplot(2,1,2)
d1['salary'].value_counts().head(10).plot.bar(color="y")
plt.show()

# %%
a = data['rank']

# %%
a.value_counts().plot.bar()
plt.show()

# %%
b = data.value_counts(data['rank'])
plt.bar(a,data['rank'])
# Out:
# <BarContainer object of 397 artists>

# %%
data.salary.value_counts().plot.pie(autopct="%.6f")
# Out:
# <Axes: ylabel='salary'>

# %%
data.salary.plot.line(marker='o')
plt.show()

# %%
data.salary.plot.hist(bins=5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
data.salary.hist()
# Out:
# <Axes: >

# %%
data.corr()
# Out:
# C:\Users\suman\AppData\Local\Temp\ipykernel_21464\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                   index  yrs.since.phd  yrs.service    salary
# index          1.000000       0.208424     0.166314  0.099583
# yrs.since.phd  0.208424       1.000000     0.909649  0.419231
# yrs.service    0.166314       0.909649     1.000000  0.334745
# salary         0.099583       0.419231     0.334745  1.000000

# %%
data.sex.value_counts().plot.bar(color=['b','r'])
plt.title("Gender frequency",loc="left")
plt.xlabel("Gender")
plt.ylabel("Frequency")
plt.ylim(0,500)
plt.yscale('linear')
plt.legend(['male'],loc="upper left",fontsize="8")
plt.grid("true")
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"E:\PES\SEM2\Refer\ML\ML_Datasets-20230613T052137Z-001\ML_Datasets\Salaries.csv")

# %%
plt.subplot(2,1,1)
sns.histplot(data=data,x='salary',kde=False)

plt.subplot(2,1,2)
sns.histplot(data=data,x='salary',kde=True)
# Out:
# <Axes: xlabel='salary', ylabel='Count'>

# %%
sns.relplot(data=data,x='salary',y='yrs.service',hue='rank')

# %%
sns.boxplot(data=data,x='salary')
# Out:
# <Axes: xlabel='salary'>

# %%
max(data['salary'])
# Out:
# 231545

# %%
d1 = data[data['salary']>200000]

# %%
d1
# Out:
#      index  rank discipline  yrs.since.phd  yrs.service   sex  salary
# 43      44  Prof          B             38           38  Male  231545
# 249    250  Prof          A             29            7  Male  204000
# 364    365  Prof          A             43           43  Male  205500

# %%
sns.lineplot(data=data,x=data.index,y='salary')
plt.show()

# %%
sns.countplot(data=data,x='rank')
# Out:
# <Axes: xlabel='rank', ylabel='count'>

# %%
sns.relplot(data=data,x='yrs.service',y='salary',hue='sex', style='rank')
plt.show()

# %%
sns.regplot(data=data,x='yrs.service',y='salary')
plt.show()

# %%
sns.swarmplot(data=data,x="sex",y='salary',hue='sex')
# Out:
# <Axes: xlabel='sex', ylabel='salary'>

# %%
sns.violinplot(data=data,x='sex',y='salary')
# Out:
# <Axes: xlabel='sex', ylabel='salary'>

# %%
sns.pairplot(data)
plt.show()
